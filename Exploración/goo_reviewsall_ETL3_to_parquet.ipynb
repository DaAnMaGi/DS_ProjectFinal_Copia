# %%
import pandas as pd
import os

# %%
# Lista para almacenar los dataframes de todos los estados
dataframes = []

# Función para procesar cada estado y ruta
def procesar_archivos_json(state, ruta_directorio):
    for filename in os.listdir(ruta_directorio):
        if filename.endswith('.json'):
            try:
                df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
                df_temporal['state'] = state
                dataframes.append(df_temporal)
            except ValueError as e:
                print(f"Error al procesar el archivo {filename}: {e}")

# %%
state = 'AL'
ruta_directorio = '../Data/Google/reviews-estados/review-Alabama/review-Alabama'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'AK'
ruta_directorio = '../Data/Google/reviews-estados/review-Alaska'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'AZ'
ruta_directorio = '../Data/Google/reviews-estados/review-Arizona'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'AR'
ruta_directorio = '../Data/Google/reviews-estados/review-Arkansas'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'CA'
ruta_directorio = '../Data/Google/reviews-estados/review-California'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'CO'
ruta_directorio = '../Data/Google/reviews-estados/review-Colorado'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'CT'
ruta_directorio = '../Data/Google/reviews-estados/review-Connecticut'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
ruta_directorio = '../'
dataframes = []

state = 'DE'
for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'District_of_Columbia'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-District_of_Columbia'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'FL'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Florida_FL'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'GA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Georgia_GA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'HI'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Hawaii_HI'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'ID'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Idaho_ID'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'IL'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Illinois_IL'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'IN'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Indiana_IN'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'IA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Iowa_IA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'KS'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Kansas_KS'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)
df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'KY'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Kentucky_KY'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'LA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Louisiana_LA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'ME'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Maine_ME'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MD'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Maryland_MD'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Massachusetts_MA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MI'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Michigan_MI'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MN'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Minnesota_MN'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MS'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Mississippi_MS'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MO'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Missouri_MO'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'MT'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Montana_MT'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NE'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Nebraska_NE'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NV'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Nevada_NV'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)
        
df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NH'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-New_Hampshire_NH'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NJ'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-New_Jersey_NJ'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NM'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-New_Mexico_NM'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NY'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-New_York_NY'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'NC'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-North_Carolina_NC'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'ND'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-North_Dakota_ND'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'OH'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Ohio_OH'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'OK'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Oklahoma_OK'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'OR'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Oregon_OR'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'PA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Pennsylvania_PA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'RI'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Rhode_Island_RI'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'SC'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-South_Carolina_SC'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'SD'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-South_Dakota_SD'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'TN'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Tennessee_TN'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'TX'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Texas_TX'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'UT'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Utah_UT'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'VT'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Vermont_VT'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)
        
df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'VA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Virginia_VA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'WA'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Washington_WA'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'WV'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-West_Virginia_WV'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'WI'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Wisconsin_WI'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)

# %%
state = 'WY'
ruta_directorio = '/Users/Juan/Documents/Academics/DataScience/PjFinal/Google/GoogleReviews/estados/review-Wyoming_WY'
dataframes = []

for filename in os.listdir(ruta_directorio):
    if filename.endswith('.json'):
        df_temporal = pd.read_json(os.path.join(ruta_directorio, filename), lines=True)
        dataframes.append(df_temporal)

df = pd.concat(dataframes, ignore_index=True)
df['state'] = state

file_name = f'../Data/Google/reviews-estados-parquet/revgoo_{state}.parquet'
df.to_parquet(file_name, index=False)
